# %% [markdown]
# <a href="https://colab.research.google.com/github/asetya/BigData/blob/master/Yolo8_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #YOLO 8

# %% [markdown]
# Prepare the environtment

# %%
# !pip install ultralytics
from ultralytics import YOLO
import cv2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Call the library

# %%
from ultralytics import YOLO
from IPython.display import Image, display

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")  # n = nano version (fastest)

# Download a sample image
# !wget https://ultralytics.com/images/bus.jpg -O bus.jpg

# Run detection
results = model("bus.jpg")

# Display result
results[0].show()
display(Image(filename="bus.jpg"))
# Out:
# ...
# --2025-10-17 14:58:52--  https://ultralytics.com/images/bus.jpg
# Resolving ultralytics.com (ultralytics.com)... 99.83.190.102, 75.2.70.75
# Connecting to ultralytics.com (ultralytics.com)|99.83.190.102|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ultralytics.com/images/bus.jpg [following]
# --2025-10-17 14:58:52--  https://www.ultralytics.com/images/bus.jpg
# Resolving www.ultralytics.com (www.ultralytics.com)... 172.64.147.154, 104.18.40.102, 2606:4700:4406::ac40:939a, ...
# Connecting to www.ultralytics.com (www.ultralytics.com)|172.64.147.154|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/ultralytics/assets/releases/download/v0.0.0/bus.jpg [following]
# --2025-10-17 14:58:52--  https://github.com/ultralytics/assets/releases/download/v0.0.0/bus.jpg
# Resolving github.com (github.com)... 140.82.112.4
# ...

# %%
# Install required packages
# !pip install ultralytics opencv-python

from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Draw detections on frame
    annotated_frame = results[0].plot()

    # Show frame
    cv2_imshow(annotated_frame)

    # Break loop with 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %% [markdown]
# #upload video dan cek obyek

# %%
from google.colab import files
uploaded = files.upload()  # Upload a video file here
# Out:
#      <input type="file" id="files-1a6a7448-e4a9-4031-a5be-99bfc1331d26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a6a7448-e4a9-4031-a5be-99bfc1331d26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Object Detection Using YOLO 8**

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # Load YOLOv8 model
input_video = list(uploaded.keys())[0]  # Use uploaded video
results = model(source=input_video, show=True, save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/171) /content/sample-5s.mp4: 384x640 3 cars, 1 truck, 72.8ms
# video 1/1 (frame 2/171) /content/sample-5s.mp4: 384x640 2 cars, 1 truck, 9.1ms
# video 1/1 (frame 3/171) /content/sample-5s.mp4: 384x640 2 cars, 1 truck, 9.4ms
# video 1/1 (frame 4/171) /content/sample-5s.mp4: 384x640 2 cars, 1 truck, 8.5ms
# ...

# %% [markdown]
# #Fast RCNN

# %%
import torch
import torchvision
from torchvision import transforms
